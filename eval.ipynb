# %%
from pycaret.regression import *
import pandas as pd

# %%
data = pd.read_csv("./Fuel_cell_performance_data-Full.csv")
# print(data)

# %% [markdown]
# Comparing models:
# 1) preprocessing = False
# 2) data split shuffle = False
# 3) normalise = False
# 4) feature selection = false
# 5) remove outliers = false

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=False, preprocess=False, normalize=False, normalize_method='zscore', feature_selection=False, remove_outliers=False)
cm = compare_models()
result_1 = pull()
# Out:
# <style type="text/css">
# #T_1fd90 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = False
# 2) data split shuffle = True
# 3) normalise = False
# 4) feature selection = false
# 5) remove outliers = false

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=False, normalize=False, normalize_method='zscore', feature_selection=False, remove_outliers=False)
cm = compare_models()
result_2 = pull()
# Out:
# <style type="text/css">
# #T_2485a th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = True
# 2) data split shuffle = True
# 3) normalise = False
# 4) feature selection = false
# 5) remove outliers = false

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=True, normalize=False, normalize_method='zscore', feature_selection=False, remove_outliers=False)
cm = compare_models()
result_3 = pull()
# Out:
# <style type="text/css">
# #T_36830 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = True
# 2) data split shuffle = True
# 3) normalise = True
# 4) feature selection = false
# 5) remove outliers = false

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=True, normalize=True, normalize_method='zscore', feature_selection=False, remove_outliers=False)
cm = compare_models()
result_4 = pull()
# Out:
# <style type="text/css">
# #T_008a4 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = True
# 2) data split shuffle = True
# 3) normalise = True
# 4) feature selection = True
# 5) remove outliers = false

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=True, normalize=True, normalize_method='zscore', feature_selection=True, remove_outliers=False)
cm = compare_models()
result_5 = pull()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000316 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3845
# [LightGBM] [Info] Number of data points in the train set: 700, number of used features: 19
# [LightGBM] [Info] Start training from score 58.776929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = True
# 2) data split shuffle = True
# 3) normalise = True
# 4) feature selection = True
# 5) remove outliers = True

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=True, normalize=True, normalize_method='zscore', feature_selection=True, remove_outliers=True)
cm = compare_models()
result_6 = pull()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3638
# [LightGBM] [Info] Number of data points in the train set: 665, number of used features: 19
# [LightGBM] [Info] Start training from score 57.968647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = True
# 2) data split shuffle = True
# 3) normalise = False
# 4) feature selection = True
# 5) remove outliers = False

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=True, normalize=False, normalize_method='zscore', feature_selection=True, remove_outliers=False)
cm = compare_models()
result_7 = pull()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000205 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3865
# [LightGBM] [Info] Number of data points in the train set: 700, number of used features: 19
# [LightGBM] [Info] Start training from score 57.228243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Comparing models:
# 1) preprocessing = False
# 2) data split shuffle = True
# 3) normalise = True
# 4) feature selection = False
# 5) remove outliers = True

# %%
s = setup(data = data, target='Target5', verbose=False, train_size = 0.7, data_split_shuffle=True, preprocess=False, normalize=True, normalize_method='zscore', feature_selection=False, remove_outliers=True)
cm = compare_models()
result_8 = pull()
# Out:
# <style type="text/css">
# #T_1c7f6 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Deciding which model is the best model :-

# %%
result_list = [result_1.iloc[0], result_2.iloc[0], result_3.iloc[0], result_4.iloc[0], result_5.iloc[0], result_6.iloc[0], result_7.iloc[0],result_8.iloc[0]]

result_df = pd.DataFrame(result_list)
# print(result_df)

avg_results = result_df.groupby("Model").mean()
# print(avg_results)

best_model_row = avg_results.loc[avg_results['R2'].idxmax()]
print(best_model_row)
# Out:
# MAE          4.940117
# MSE         55.877133
# RMSE         7.312267
# R2           0.971733
# RMSLE        0.137100
# MAPE         0.114567
# TT (Sec)     0.201000
# Name: Extra Trees Regressor, dtype: float64
